# %%
import numpy as np
import utility
import random

from qubo_solver import QuboSolver
from routes import Route
from visual import Visual
from PIL import Image, ImageDraw
from simulation import Simulation

# %%
"""Definining the number of shuttles, the initial number of passengers, the central node, and the total number of nodes.
    n: Initial number of passengers.
    m: Number of shuttles.
    center: Index of central node.
    total_nodes: Total number of nodes.
"""

n = 5
m = 2
center = 86
total_nodes=122

# %%
# Generate the initial set of requests.
requests = utility.generate_initial_requests(n, center, total_nodes)
print(requests)
# Show the requests generated on the map.
initial_request_view = Visual(center, node_size=10)
initial_request_view.draw_initial_requests(requests)
initial_request_view.show()
# Out:
# [ 24  10  40 111 121]

# %%
# Generate the VRP instance
instance, xc, yc = utility.generate_vrp_instance(n, center, requests)

# %%
# Initialize the QUBO instance and solve
qs = QuboSolver(n, m, instance)
qs.solve()

# %%
# Visualize the solution as a graph
qs.visualize(xc, yc)

# %%
# Retrieve the clusters from the solution
clusters = qs.get_clusters()

# %%
print(clusters)
# Out:
# [[2, 3, 5], [4, 1]]

# %%
# Create the simulation instance
sim = Simulation(m, n, center, total_nodes, clusters, requests, folder='test')
# Out:
# Number: WB55W6241	Number of Passengers: 3		Current Position: 86	 Route : [86, 85, 84, 71, 55, 41, 20, 21, 20, 19, 18, 13] 	Drop order: [(86, 20), (86, 21), (86, 13)]
# ID: P019KP9860	Request Info: (86, 20)	 Shuttle Number: WB55W6241
# ID: P504HM8618	Request Info: (86, 21)	 Shuttle Number: WB55W6241
# ID: P009CS6541	Request Info: (86, 13)	 Shuttle Number: WB55W6241
# Number: WB58V9883	Number of Passengers: 2		Current Position: 86	 Route : [86, 87, 97, 100, 98, 99, 98, 65, 64, 31, 30, 29] 	Drop order: [(86, 99), (86, 29)]
# ID: P921TZ7006	Request Info: (86, 99)	 Shuttle Number: WB58V9883
# ID: P376VI3525	Request Info: (86, 29)	 Shuttle Number: WB58V9883

# %%
# Run the simulation for 30 iterations
sim.simulate(30)
# Out:
# 	###Simulation Starting###
#
#
# Iteration  1
# Request generated:  (110, 21)
# 1	68	110	2106
# 2	69	110	2630
# 3	58	110	2847
# Source Point: -1
# Destination Point: -1
# 1	87	110	1414
# 2	97	110	1069
# 3	96	110	915
# Source Point: 3
# Destination Point: -1
#
# No suitable shuttles
#
#
# Number: WB95S4330	Number of Passengers: 3		Current Position: 68	Route : [86, 68, 69, 58, 37, 24, 37, 38, 39, 40, 21, 10]	Drop order: [(86, 24), (86, 40), (86, 10)]	Service: False	Pickup: None
# Number: WB75Y6796	Number of Passengers: 2		Current Position: 87	Route : [86, 87, 97, 96, 95, 101, 110, 111, 119, 120, 121]	Drop order: [(86, 111), (86, 121)]	Service: False	Pickup: None
#
# Iteration  2
# Request generated:  (37, 58)
# 2	69	37	543
# 3	58	37	326
# 4	37	37	0
# Source Point: 4
# Destination Point: 3
# 2	97	37	2137
# 3	96	37	2291
# 4	95	37	2528
# Source Point: -1
# Destination Point: -1
#
# Suitable Shuttles:
# Distance: 543	 Number: WB95S4330	Number of Passengers: 3		Current Position: 69	 Route : [86, 68, 69, 58, 37, 24, 37, 38, 39, 40, 21, 10] 	Drop order: [(86, 24), (86, 40), (86, 10)]
# Selected Shuttle:  WB95S4330
#
#
# Number: WB95S4330	Number of Passengers: 3		Current Position: 69	Route : [86, 68, 69, 58, 37, 58, 37, 24, 37, 38, 39, 40, 21, 10]	Drop order: [(37, 58), (86, 24), (86, 40), (86, 10)]	Service: True	Pickup: (37, 58)
# Number: WB75Y6796	Number of Passengers: 2		Current Position: 97	Route : [86, 87, 97, 96, 95, 101, 110, 111, 119, 120, 121]	Drop order: [(86, 111), (86, 121)]	Service: False	Pickup: None
#
# Iteration  3
# Request generated:  (0, 26)
# 3	96	0	2014
# 4	95	0	2251
# 5	101	0	2114
# Source Point: -1
# Destination Point: -1
#
# No suitable shuttles
#
#
# Number: WB95S4330	Number of Passengers: 3		Current Position: 58	Route : [86, 68, 69, 58, 37, 58, 37, 24, 37, 38, 39, 40, 21, 10]	Drop order: [(37, 58), (86, 24), (86, 40), (86, 10)]	Service: True	Pickup: (37, 58)
# Number: WB75Y6796	Number of Passengers: 2		Current Position: 96	Route : [86, 87, 97, 96, 95, 101, 110, 111, 119, 120, 121]	Drop order: [(86, 111), (86, 121)]	Service: False	Pickup: None
#
# Iteration  4
# ID: P759XV3663	Request Info: (86, 24)	 Shuttle Number: WB95S4330
# ID: P852IO8829	Request Info: (86, 40)	 Shuttle Number: WB95S4330
# ID: P881CY6956	Request Info: (86, 10)	 Shuttle Number: WB95S4330
# Passenger picked up at 37 by car WB95S4330
# Request generated:  (89, 71)
# 4	95	89	321
# 5	101	89	633
# 6	110	89	999
# Source Point: 4
# Destination Point: -1
#
# No suitable shuttles
#
#
# Number: WB95S4330	Number of Passengers: 4		Current Position: 37	Route : [86, 68, 69, 58, 37, 58, 37, 24, 37, 38, 39, 40, 21, 10]	Drop order: [(37, 58), (86, 24), (86, 40), (86, 10)]	Service: False	Pickup: None
# Number: WB75Y6796	Number of Passengers: 2		Current Position: 95	Route : [86, 87, 97, 96, 95, 101, 110, 111, 119, 120, 121]	Drop order: [(86, 111), (86, 121)]	Service: False	Pickup: None
#
# Iteration  5
# Passenger dropped up at 58 by car WB95S4330
# Request generated:  (103, 116)
# 3	58	103	2730
# 4	37	103	3056
# 5	58	103	2730
# Source Point: -1
# Destination Point: -1
# 5	101	103	842
# 6	110	103	1208
# 7	111	103	1181
# Source Point: 5
# Destination Point: 9
#
# Suitable Shuttles:
# Distance: 842	 Number: WB75Y6796	Number of Passengers: 2		Current Position: 101	 Route : [86, 87, 97, 96, 95, 101, 110, 111, 119, 120, 121] 	Drop order: [(86, 111), (86, 121)]
# Selected Shuttle:  WB75Y6796
#
#
# Number: WB95S4330	Number of Passengers: 3		Current Position: 58	Route : [86, 68, 69, 58, 37, 58, 37, 24, 37, 38, 39, 40, 21, 10]	Drop order: [(86, 24), (86, 40), (86, 10)]	Service: False	Pickup: None
# Number: WB75Y6796	Number of Passengers: 2		Current Position: 101	Route : [86, 87, 97, 96, 95, 101, 102, 103, 108, 109, 111, 119, 118, 117, 116, 115, 121]	Drop order: [(86, 111), (103, 116), (86, 121)]	Service: True	Pickup: (103, 116)
#
# Iteration  6
# Request generated:  (67, 82)
# 4	37	67	1395
# 5	58	67	1069
# 6	37	67	1395
# Source Point: -1
# Destination Point: -1
#
# No suitable shuttles
#
#
# Number: WB95S4330	Number of Passengers: 3		Current Position: 37	Route : [86, 68, 69, 58, 37, 58, 37, 24, 37, 38, 39, 40, 21, 10]	Drop order: [(86, 24), (86, 40), (86, 10)]	Service: False	Pickup: None
# Number: WB75Y6796	Number of Passengers: 2		Current Position: 102	Route : [86, 87, 97, 96, 95, 101, 102, 103, 108, 109, 111, 119, 118, 117, 116, 115, 121]	Drop order: [(86, 111), (103, 116), (86, 121)]	Service: True	Pickup: (103, 116)
#
# Iteration  7
# Passenger dropped up at 24 by car WB95S4330
# ID: P257TB1978	Request Info: (86, 111)	 Shuttle Number: WB75Y6796
# ID: P958ZK9651	Request Info: (86, 121)	 Shuttle Number: WB75Y6796
# Passenger picked up at 103 by car WB75Y6796
# Request generated:  (6, 100)
# 7	24	6	419
# 8	37	6	733
# 9	38	6	1328
# Source Point: 7
# Destination Point: -1
# 7	103	6	3789
# 8	108	6	4116
# 9	109	6	4137
# Source Point: -1
# Destination Point: -1
#
# No suitable shuttles
#
#
# Number: WB95S4330	Number of Passengers: 2		Current Position: 24	Route : [86, 68, 69, 58, 37, 58, 37, 24, 37, 38, 39, 40, 21, 10]	Drop order: [(86, 40), (86, 10)]	Service: False	Pickup: None
# Number: WB75Y6796	Number of Passengers: 3		Current Position: 103	Route : [86, 87, 97, 96, 95, 101, 102, 103, 108, 109, 111, 119, 118, 117, 116, 115, 121]	Drop order: [(86, 111), (103, 116), (86, 121)]	Service: False	Pickup: None
#
# Iteration  8
# Request generated:  (99, 8)
# 4	37	99	2460
# 5	58	99	2134
# 6	37	99	2460
# Source Point: -1
# Destination Point: -1
# 8	108	99	2044
# 9	109	99	1656
# 10	111	99	1190
# Source Point: -1
# Destination Point: -1
#
# No suitable shuttles
#
#
# Number: WB95S4330	Number of Passengers: 2		Current Position: 37	Route : [86, 68, 69, 58, 37, 58, 37, 24, 37, 38, 39, 40, 21, 10]	Drop order: [(86, 40), (86, 10)]	Service: False	Pickup: None
# Number: WB75Y6796	Number of Passengers: 3		Current Position: 108	Route : [86, 87, 97, 96, 95, 101, 102, 103, 108, 109, 111, 119, 118, 117, 116, 115, 121]	Drop order: [(86, 111), (103, 116), (86, 121)]	Service: False	Pickup: None
#
# Iteration  9
# Request generated:  (61, 106)
# 9	38	61	1635
# 10	39	61	1633
# 11	40	61	1805
# Source Point: -1
# Destination Point: -1
# 9	109	61	2560
# 10	111	61	2806
# 11	119	61	3306
# Source Point: -1
# Destination Point: -1
#
# No suitable shuttles
#
#
# Number: WB95S4330	Number of Passengers: 2		Current Position: 38	Route : [86, 68, 69, 58, 37, 58, 37, 24, 37, 38, 39, 40, 21, 10]	Drop order: [(86, 40), (86, 10)]	Service: False	Pickup: None
# Number: WB75Y6796	Number of Passengers: 3		Current Position: 109	Route : [86, 87, 97, 96, 95, 101, 102, 103, 108, 109, 111, 119, 118, 117, 116, 115, 121]	Drop order: [(86, 111), (103, 116), (86, 121)]	Service: False	Pickup: None
#
# Iteration  10
# Passenger dropped up at 111 by car WB75Y6796
# Request generated:  (15, 71)
# 10	39	15	3833
# 11	40	15	3754
# 12	21	15	4050
# Source Point: -1
# Destination Point: -1
# 10	111	15	4944
# 11	119	15	4995
# 12	118	15	4622
# Source Point: -1
# Destination Point: -1
#
# No suitable shuttles
#
#
# Number: WB95S4330	Number of Passengers: 2		Current Position: 39	Route : [86, 68, 69, 58, 37, 58, 37, 24, 37, 38, 39, 40, 21, 10]	Drop order: [(86, 40), (86, 10)]	Service: False	Pickup: None
# Number: WB75Y6796	Number of Passengers: 2		Current Position: 111	Route : [86, 87, 97, 96, 95, 101, 102, 103, 108, 109, 111, 119, 118, 117, 116, 115, 121]	Drop order: [(103, 116), (86, 121)]	Service: False	Pickup: None
#
# Iteration  11
# Passenger dropped up at 40 by car WB95S4330
# Request generated:  (68, 82)
# 11	40	68	1625
# 12	21	68	1927
# 13	10	68	2152
# Source Point: -1
# Destination Point: -1
# 11	119	68	3083
# 12	118	68	2990
# 13	117	68	3174
# Source Point: -1
# Destination Point: -1
#
# No suitable shuttles
#
#
# Number: WB95S4330	Number of Passengers: 1		Current Position: 40	Route : [86, 68, 69, 58, 37, 58, 37, 24, 37, 38, 39, 40, 21, 10]	Drop order: [(86, 10)]	Service: False	Pickup: None
# Number: WB75Y6796	Number of Passengers: 2		Current Position: 119	Route : [86, 87, 97, 96, 95, 101, 102, 103, 108, 109, 111, 119, 118, 117, 116, 115, 121]	Drop order: [(103, 116), (86, 121)]	Service: False	Pickup: None
#
# Iteration  12
# Request generated:  (53, 47)
# 12	21	53	1485
# 13	10	53	1709
# Source Point: -1
# Destination Point: -1
# 12	118	53	3244
# 13	117	53	3060
# 14	116	53	2905
# Source Point: -1
# Destination Point: -1
#
# No suitable shuttles
#
#
# Number: WB95S4330	Number of Passengers: 1		Current Position: 21	Route : [86, 68, 69, 58, 37, 58, 37, 24, 37, 38, 39, 40, 21, 10]	Drop order: [(86, 10)]	Service: False	Pickup: None
# Number: WB75Y6796	Number of Passengers: 2		Current Position: 118	Route : [86, 87, 97, 96, 95, 101, 102, 103, 108, 109, 111, 119, 118, 117, 116, 115, 121]	Drop order: [(103, 116), (86, 121)]	Service: False	Pickup: None
#
# Iteration  13
# Passenger dropped up at 10 by car WB95S4330
# Request generated:  (54, 14)
# 13	117	54	2924
# 14	116	54	2769
# 15	115	54	2877
# Source Point: -1
# Destination Point: -1
#
# Suitable Shuttles:
# Distance: 1590	 Number: WB95S4330	Number of Passengers: 0		Current Position: 10	 Route : [] 	Drop order: []
# Selected Shuttle:  WB95S4330
#
#
# Number: WB95S4330	Number of Passengers: 0		Current Position: 10	Route : [10, 11, 20, 41, 55, 54, 72, 73, 51, 50, 49, 46, 16, 14]	Drop order: [(54, 14)]	Service: True	Pickup: (54, 14)
# Number: WB75Y6796	Number of Passengers: 2		Current Position: 117	Route : [86, 87, 97, 96, 95, 101, 102, 103, 108, 109, 111, 119, 118, 117, 116, 115, 121]	Drop order: [(103, 116), (86, 121)]	Service: False	Pickup: None
#
# Iteration  14
# Passenger dropped up at 116 by car WB75Y6796
# Request generated:  (40, 110)
# 14	116	40	3837
# 15	115	40	3945
# 16	121	40	4595
# Source Point: -1
# Destination Point: -1
#
# No suitable shuttles
#
#
# Number: WB95S4330	Number of Passengers: 0		Current Position: 11	Route : [10, 11, 20, 41, 55, 54, 72, 73, 51, 50, 49, 46, 16, 14]	Drop order: [(54, 14)]	Service: True	Pickup: (54, 14)
# Number: WB75Y6796	Number of Passengers: 1		Current Position: 116	Route : [86, 87, 97, 96, 95, 101, 102, 103, 108, 109, 111, 119, 118, 117, 116, 115, 121]	Drop order: [(86, 121)]	Service: False	Pickup: None
#
# Iteration  15
# Request generated:  (60, 90)
# 15	115	60	4243
# 16	121	60	4424
# Source Point: -1
# Destination Point: -1
#
# No suitable shuttles
#
#
# Number: WB95S4330	Number of Passengers: 0		Current Position: 20	Route : [10, 11, 20, 41, 55, 54, 72, 73, 51, 50, 49, 46, 16, 14]	Drop order: [(54, 14)]	Service: True	Pickup: (54, 14)
# Number: WB75Y6796	Number of Passengers: 1		Current Position: 115	Route : [86, 87, 97, 96, 95, 101, 102, 103, 108, 109, 111, 119, 118, 117, 116, 115, 121]	Drop order: [(86, 121)]	Service: False	Pickup: None
#
# Iteration  16
# Passenger dropped up at 121 by car WB75Y6796
# Request generated:  (22, 119)
#
# No suitable shuttles
#
#
# Number: WB95S4330	Number of Passengers: 0		Current Position: 41	Route : [10, 11, 20, 41, 55, 54, 72, 73, 51, 50, 49, 46, 16, 14]	Drop order: [(54, 14)]	Service: True	Pickup: (54, 14)
# Number: WB75Y6796	Number of Passengers: 0		Current Position: 121	Route : []	Drop order: []	Service: False	Pickup: None
#
# Iteration  17
# Request generated:  (25, 81)
#
# No suitable shuttles
#
#
# Number: WB95S4330	Number of Passengers: 0		Current Position: 55	Route : [10, 11, 20, 41, 55, 54, 72, 73, 51, 50, 49, 46, 16, 14]	Drop order: [(54, 14)]	Service: True	Pickup: (54, 14)
# Number: WB75Y6796	Number of Passengers: 0		Current Position: 121	Route : []	Drop order: []	Service: False	Pickup: None
#
# Iteration  18
# Passenger picked up at 54 by car WB95S4330
# Request generated:  (60, 17)
# 5	54	60	1738
# 6	72	60	1595
# 7	73	60	1738
# Source Point: -1
# Destination Point: -1
#
# No suitable shuttles
#
#
# Number: WB95S4330	Number of Passengers: 1		Current Position: 54	Route : [10, 11, 20, 41, 55, 54, 72, 73, 51, 50, 49, 46, 16, 14]	Drop order: [(54, 14)]	Service: False	Pickup: None
# Number: WB75Y6796	Number of Passengers: 0		Current Position: 121	Route : []	Drop order: []	Service: False	Pickup: None
#
# Iteration  19
# Request generated:  (48, 14)
# 6	72	48	2164
# 7	73	48	2021
# 8	51	48	1661
# Source Point: -1
# Destination Point: -1
#
# No suitable shuttles
#
#
# Number: WB95S4330	Number of Passengers: 1		Current Position: 72	Route : [10, 11, 20, 41, 55, 54, 72, 73, 51, 50, 49, 46, 16, 14]	Drop order: [(54, 14)]	Service: False	Pickup: None
# Number: WB75Y6796	Number of Passengers: 0		Current Position: 121	Route : []	Drop order: []	Service: False	Pickup: None
#
# Iteration  20
# Request generated:  (1, 61)
# 7	73	1	3699
# 8	51	1	3929
# 9	50	1	4569
# Source Point: -1
# Destination Point: -1
#
# No suitable shuttles
#
#
# Number: WB95S4330	Number of Passengers: 1		Current Position: 73	Route : [10, 11, 20, 41, 55, 54, 72, 73, 51, 50, 49, 46, 16, 14]	Drop order: [(54, 14)]	Service: False	Pickup: None
# Number: WB75Y6796	Number of Passengers: 0		Current Position: 121	Route : []	Drop order: []	Service: False	Pickup: None
#
# Iteration  21
# Request generated:  (25, 51)
# 8	51	25	2884
# 9	50	25	3524
# 10	49	25	4040
# Source Point: -1
# Destination Point: -1
#
# No suitable shuttles
#
#
# Number: WB95S4330	Number of Passengers: 1		Current Position: 51	Route : [10, 11, 20, 41, 55, 54, 72, 73, 51, 50, 49, 46, 16, 14]	Drop order: [(54, 14)]	Service: False	Pickup: None
# Number: WB75Y6796	Number of Passengers: 0		Current Position: 121	Route : []	Drop order: []	Service: False	Pickup: None
#
# Iteration  22
# Request generated:  (84, 68)
# 9	50	84	1778
# 10	49	84	2294
# 11	46	84	2531
# Source Point: -1
# Destination Point: -1
#
# No suitable shuttles
#
#
# Number: WB95S4330	Number of Passengers: 1		Current Position: 50	Route : [10, 11, 20, 41, 55, 54, 72, 73, 51, 50, 49, 46, 16, 14]	Drop order: [(54, 14)]	Service: False	Pickup: None
# Number: WB75Y6796	Number of Passengers: 0		Current Position: 121	Route : []	Drop order: []	Service: False	Pickup: None
#
# Iteration  23
# Request generated:  (67, 25)
# 10	49	67	3679
# 11	46	67	3916
# 12	16	67	4106
# Source Point: -1
# Destination Point: -1
#
# No suitable shuttles
#
#
# Number: WB95S4330	Number of Passengers: 1		Current Position: 49	Route : [10, 11, 20, 41, 55, 54, 72, 73, 51, 50, 49, 46, 16, 14]	Drop order: [(54, 14)]	Service: False	Pickup: None
# Number: WB75Y6796	Number of Passengers: 0		Current Position: 121	Route : []	Drop order: []	Service: False	Pickup: None
#
# Iteration  24
# Request generated:  (65, 106)
# 11	46	65	4514
# 12	16	65	4704
# 13	14	65	5046
# Source Point: -1
# Destination Point: -1
#
# Suitable Shuttles:
# Distance: 2700	 Number: WB75Y6796	Number of Passengers: 0		Current Position: 121	 Route : [] 	Drop order: []
# Selected Shuttle:  WB75Y6796
#
#
# Number: WB95S4330	Number of Passengers: 1		Current Position: 46	Route : [10, 11, 20, 41, 55, 54, 72, 73, 51, 50, 49, 46, 16, 14]	Drop order: [(54, 14)]	Service: False	Pickup: None
# Number: WB75Y6796	Number of Passengers: 0		Current Position: 121	Route : [121, 120, 119, 111, 110, 99, 98, 65, 98, 100, 101, 102, 103, 108, 107, 106]	Drop order: [(65, 106)]	Service: True	Pickup: (65, 106)
#
# Iteration  25
# Request generated:  (55, 105)
# 12	16	55	2561
# 13	14	55	2903
# Source Point: -1
# Destination Point: -1
#
# No suitable shuttles
#
#
# Number: WB95S4330	Number of Passengers: 1		Current Position: 16	Route : [10, 11, 20, 41, 55, 54, 72, 73, 51, 50, 49, 46, 16, 14]	Drop order: [(54, 14)]	Service: False	Pickup: None
# Number: WB75Y6796	Number of Passengers: 0		Current Position: 120	Route : [121, 120, 119, 111, 110, 99, 98, 65, 98, 100, 101, 102, 103, 108, 107, 106]	Drop order: [(65, 106)]	Service: True	Pickup: (65, 106)
#
# Iteration  26
# Passenger dropped up at 14 by car WB95S4330
# Request generated:  (19, 103)
#
# No suitable shuttles
#
#
# Number: WB95S4330	Number of Passengers: 0		Current Position: 14	Route : []	Drop order: []	Service: False	Pickup: None
# Number: WB75Y6796	Number of Passengers: 0		Current Position: 119	Route : [121, 120, 119, 111, 110, 99, 98, 65, 98, 100, 101, 102, 103, 108, 107, 106]	Drop order: [(65, 106)]	Service: True	Pickup: (65, 106)
#
# Iteration  27
# Request generated:  (34, 17)
#
# No suitable shuttles
#
#
# Number: WB95S4330	Number of Passengers: 0		Current Position: 14	Route : []	Drop order: []	Service: False	Pickup: None
# Number: WB75Y6796	Number of Passengers: 0		Current Position: 111	Route : [121, 120, 119, 111, 110, 99, 98, 65, 98, 100, 101, 102, 103, 108, 107, 106]	Drop order: [(65, 106)]	Service: True	Pickup: (65, 106)
#
# Iteration  28
# Request generated:  (35, 44)
#
# No suitable shuttles
#
#
# Number: WB95S4330	Number of Passengers: 0		Current Position: 14	Route : []	Drop order: []	Service: False	Pickup: None
# Number: WB75Y6796	Number of Passengers: 0		Current Position: 110	Route : [121, 120, 119, 111, 110, 99, 98, 65, 98, 100, 101, 102, 103, 108, 107, 106]	Drop order: [(65, 106)]	Service: True	Pickup: (65, 106)
#
# Iteration  29
# Request generated:  (40, 118)
#
# No suitable shuttles
#
#
# Number: WB95S4330	Number of Passengers: 0		Current Position: 14	Route : []	Drop order: []	Service: False	Pickup: None
# Number: WB75Y6796	Number of Passengers: 0		Current Position: 99	Route : [121, 120, 119, 111, 110, 99, 98, 65, 98, 100, 101, 102, 103, 108, 107, 106]	Drop order: [(65, 106)]	Service: True	Pickup: (65, 106)
#
# Iteration  30
# Request generated:  (91, 86)
#
# Suitable Shuttles:
# Distance: 2697	 Number: WB95S4330	Number of Passengers: 0		Current Position: 14	 Route : [] 	Drop order: []
# Selected Shuttle:  WB95S4330
#
#
# Number: WB95S4330	Number of Passengers: 0		Current Position: 14	Route : [14, 16, 46, 49, 50, 51, 74, 91, 83, 84, 85, 86]	Drop order: [(91, 86)]	Service: True	Pickup: (91, 86)
# Number: WB75Y6796	Number of Passengers: 0		Current Position: 98	Route : [121, 120, 119, 111, 110, 99, 98, 65, 98, 100, 101, 102, 103, 108, 107, 106]	Drop order: [(65, 106)]	Service: True	Pickup: (65, 106)
